# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 33.04008140835951 -82.79415377694977
# -43.397112357977214 -143.5434830715158
# 51.4797405644035 -16.621132486739185
# -36.396174875158906 -115.86057588763265
# 85.49607779228845 50.708793821568094
# 1.8753899070088096 -136.3854844908583
# 28.809290897567877 45.97924730404188
# 61.436704201553624 -3.285313038888262
# -50.65745854501047 -90.13374165121823
# 0.3894094270006576 -10.163860136836576
# -18.377916253675934 -7.186533791698366
# 11.394247411105226 -24.470323599773252
# 21.92934290104435 -142.10006410033327
# 60.811421280683106 170.50953005220157
# 15.026761153002326 -73.72935493876737
# -64.94566379864955 -74.09560852155107
# 12.130534146537386 143.40810367293733
# 74.5781394806234 -109.69591850449827
# 81.33383999025057 -129.59375006376374
# -6.044780779563567 -86.88361301257778
# 13.368912250094738 111.73381637736878
# 63.87810734853258 -175.513804512429
# -53.28715693052139 -124.60605368641413
# 46.52182409322464 -84.21667484386116
# ...

# %%
#from zipfile import ZipFile
file_name = zip(lats, lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Use the tuple() function to display the latitude and longitude combinations.
lst_cityname=[]
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
    lst_cityname.append(citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
# Out:
# milledgeville us
# mataura pf
# dingle ie
# rikitea pf
# belushya guba ru
# atuona pf
# doha kw
# brae gb
# castro cl
# harper lr
# jamestown sh
# sao filipe cv
# hilo us
# tilichiki ru
# les cayes ht
# ushuaia ar
# airai pw
# yellowknife ca
# tuktoyaktuk ca
# san cristobal ec
# tuy hoa vn
# provideniya ru
# rikitea pf
# sault sainte marie ca
# natal br
# mataura pf
# qaanaaq gl
# zhigansk ru
# albany au
# half moon bay us
# rikitea pf
# butaritari ki
# hithadhoo mv
# nikolskoye ru
# almeirim br
# faanui pf
# saint-philippe re
# nikolskoye ru
# karaul ru
# illoqqortoormiut gl
# oktyabrskoye ru
# madimba tz
# kavieng pg
# dikson ru
# mackenzie ca
# deputatskiy ru
# aquiraz br
# porbandar in
# dalmatovo ru
# kapaa us
# kapaa us
# ballina ie
# mataura pf
# saint-georges gf
# bremervorde de
# saint-philippe re
# atuona pf
# comodoro rivadavia ar
# mataura pf
# pevek ru
# port alfred za
# bolungarvik is
# punta alta ar
# hilo us
# port alfred za
# san cristobal ec
# busselton au
# ...

# %%
print(lst_cityname)
# Out:
# ['milledgeville', 'mataura', 'dingle', 'rikitea', 'belushya guba', 'atuona', 'doha', 'brae', 'castro', 'harper', 'jamestown', 'sao filipe', 'hilo', 'tilichiki', 'les cayes', 'ushuaia', 'airai', 'yellowknife', 'tuktoyaktuk', 'san cristobal', 'tuy hoa', 'provideniya', 'rikitea', 'sault sainte marie', 'natal', 'mataura', 'qaanaaq', 'zhigansk', 'albany', 'half moon bay', 'rikitea', 'butaritari', 'hithadhoo', 'nikolskoye', 'almeirim', 'faanui', 'saint-philippe', 'nikolskoye', 'karaul', 'illoqqortoormiut', 'oktyabrskoye', 'madimba', 'kavieng', 'dikson', 'mackenzie', 'deputatskiy', 'aquiraz', 'porbandar', 'dalmatovo', 'kapaa', 'kapaa', 'ballina', 'mataura', 'saint-georges', 'bremervorde', 'saint-philippe', 'atuona', 'comodoro rivadavia', 'mataura', 'pevek', 'port alfred', 'bolungarvik', 'punta alta', 'hilo', 'port alfred', 'san cristobal', 'busselton', 'albany', 'barentsburg', 'atuona', 'hobart', 'nanortalik', 'grand river south east', 'taolanaro', 'chuy', 'hermanus', 'fort nelson', 'rikite
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
city_data_list = []

# %%
api_key = weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key +"&q="

    
for city in cities:
    try : 
        response = requests.get(url +city )
        print(response.url)    
    except:
        print("City not found. Skipping...")
        pass
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=milledgeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=belushya%20guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=brae
# ...

# %%
len(cities)
# Out:
# 743

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
import time 

api_key = weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

    
for city in cities:
    time.sleep(2)
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        
        city_data_dict["city_lat"] = city_weather["coord"]["lat"]
        city_data_dict["city_lng"] = city_weather["coord"]["lon"]
        city_data_dict["city_max_temp"] = city_weather["main"]["temp_max"]
        city_data_dict["city_humidity"] = city_weather["main"]["humidity"]
        city_data_dict["city_clouds"] = city_weather["clouds"]["all"]
        city_data_dict["city_wind"] = city_weather["wind"]["speed"]
        city_data_dict["city_country"] = city_weather["sys"]["country"]
        city_data_dict["city_description"] = city_weather["main"]["description"]
        #Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data_list.append({"City": city,
                          "Lat": city_weather["coord"]["lat"],
                          "Lng": city_weather["coord"]["lon"],
                          "Max Temp": city_weather["main"]["temp_max"],
                          "Humidity": city_weather["main"]["humidity"],
                          "Cloudiness": city_weather["clouds"]["all"],
                          "Wind Speed": city_weather["wind"]["speed"],
                          "Country": city_weather["sys"]["country"],
                          "Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=milledgeville
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=mataura
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=dingle
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=rikitea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=belushya+guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=atuona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7aa61bb7fc3662875a90751279c614e&q=doha
# ...

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(4): #range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        print(city_weather["coord"]["lat"])
        city_lng = city_weather["coord"]["lon"]
        #city_max_temp = city_weather["main"]["temp_max"]
        #city_humidity = city_weather["main"]["humidity"]
        #city_clouds = city_weather["clouds"]["all"]
        #city_wind = city_weather["wind"]["speed"]
        #city_country = city_weather["sys"]["country"]
        #city_current = city_weather["weather"]["description"]
        print(city_weather["weather"]["description"])
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        #city_data.append({"City": city.title(),
                          #"Lat": city_lat,
                          #"Lng": city_lng,
                          #"Max Temp": city_max_temp,
                          #"Humidity": city_humidity,
                          #"Cloudiness": city_clouds,
                          #"Wind Speed": city_wind,
                          #"Country": city_country,
                          #"Date": city_date,
                          #"Current_Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | milledgeville
# {'cod': 429, 'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# {'cod': 429, 'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}
# City not found. Skipping...
# Processing Record 3 of Set 1 | dingle
# {'cod': 429, 'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# ...

# %%
len(city_data)
# Out:
# 0

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",
                    "Current Description", "Rain (inches)","Snow (inches)"]
# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-e17caf6215c3> in <module>
#       4                     "Current Description", "Rain (inches)","Snow (inches)"]
#       5 # Assign a new or the same DataFrame the new column order.
# ----> 6 city_data_df = city_data_df[new_column_order]
#       7 city_data_df.head(10)
#
# ~/miniconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/miniconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
# ...
